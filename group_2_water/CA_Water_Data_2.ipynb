# %%
import pandas as pd

# %%
df=pd.read_csv("water_use_NaN.dat",sep="\t")

# %%
df
# Out:
#      state_cd  state_name  county_cd         county_nm  year  \
# 0           6  California          1    Alameda County  1985
# 1           6  California          1    Alameda County  1990
# 2           6  California          1    Alameda County  1995
# 3           6  California          1    Alameda County  2000
# 4           6  California          1    Alameda County  2005
# 5           6  California          1    Alameda County  2010
# 6           6  California          3     Alpine County  1985
# 7           6  California          3     Alpine County  1990
# 8           6  California          3     Alpine County  1995
# 9           6  California          3     Alpine County  2000
# 10          6  California          3     Alpine County  2005
# 11          6  California          3     Alpine County  2010
# 12          6  California          5     Amador County  1985
# 13          6  California          5     Amador County  1990
# ...

# %%
df.groupby("year").describe()
# Out:
#             Commercial consumptive use, fresh, in Mgal/d  \
# year
# 1985 count                                     58.000000
#      mean                                       5.704655
#      std                                       12.993694
#      min                                        0.010000
#      25%                                        0.397500
#      50%                                        1.640000
#      75%                                        5.237500
#      max                                       91.390000
# 1990 count                                     58.000000
#      mean                                       0.122414
#      std                                        0.559910
#      min                                        0.000000
#      25%                                        0.000000
#      50%                                        0.000000
#      75%                                        0.000000
# ...

# %%
years=df.groupby("year")

# %%
years.median().plot()

# %%
years[["Public Supply population served by groundwater, in thousands"]+["Public Supply population served by surface water, in thousands"]].median().plot()

# %%
years=df.groupby("year")

# %%
years[["Public Supply population served by groundwater, in thousands"]+["Public Supply population served by surface water, in thousands"]].median().plot()

# %%
counties=df.groupby("county_nm")

# %%
counties[["Public Supply population served by groundwater, in thousands"]+["Public Supply population served by surface water, in thousands"]].median().plot()

# %%
years[["Irrigation, Golf Courses total irrigation for golf courses, in thousand acres"]+["Irrigation, Crop total irrigation for crops, in thousand acres"]].median().describe()
# Out:
#        Irrigation, Golf Courses total irrigation for golf courses, in thousand acres  \
# count                                           2.000000
# mean                                            0.692500
# std                                             0.003536
# min                                             0.690000
# 25%                                             0.691250
# 50%                                             0.692500
# 75%                                             0.693750
# max                                             0.695000
#
#        Irrigation, Crop total irrigation for crops, in thousand acres
# count                                           2.000000
# mean                                           58.247500
# std                                            10.532356
# min                                            50.800000
# 25%                                            54.523750
# 50%                                            58.247500
# ...

# %%
counties[["Public Supply deliveries to domestic, in Mgal/d"]+["Public Supply deliveries to commercial, in Mgal/d"]+["Public Supply deliveries to industrial, in Mgal/d"]+["Public Supply deliveries to thermoelectric, in Mgal/d"]].median().plot()

# %%
years[["Public Supply deliveries to domestic, in Mgal/d"]].median().plot()

# %%
df[df.county_cd==37]
# Out:
#      state_cd  state_name  county_cd           county_nm  year  \
# 108         6  California         37  Los Angeles County  1985
# 109         6  California         37  Los Angeles County  1990
# 110         6  California         37  Los Angeles County  1995
# 111         6  California         37  Los Angeles County  2000
# 112         6  California         37  Los Angeles County  2005
# 113         6  California         37  Los Angeles County  2010
#
#      Total Population total population of area, in thousands  \
# 108                                           8105.540
# 109                                           8863.110
# 110                                           9352.200
# 111                                           9519.340
# 112                                           9935.475
# 113                                           9818.605
#
#      Public Supply population served by groundwater, in thousands  \
# 108                                           5875.350
# ...

# %%
years[["Irrigation, Total selfNaNsupplied surfaceNaNwater withdrawals, fresh, in Mgal/d"]+["Irrigation, Total selfNaNsupplied groundwater withdrawals, fresh, in Mgal/d"]].median().plot()

# %%
counties[["Irrigation, Total selfNaNsupplied surfaceNaNwater withdrawals, fresh, in Mgal/d"]+["Irrigation, Total selfNaNsupplied groundwater withdrawals, fresh, in Mgal/d"]].median().plot()

# %%
df=pd.read_csv("Three_counties.dat",sep="\t")

# %%
df
# Out:
#     state_cd  state_name  county_cd           county_nm  year  \
# 0          6  California         37  Los Angeles County  1985
# 1          6  California         37  Los Angeles County  1990
# 2          6  California         37  Los Angeles County  1995
# 3          6  California         37  Los Angeles County  2000
# 4          6  California         37  Los Angeles County  2005
# 5          6  California         37  Los Angeles County  2010
# 6          6  California         41        Marin County  1985
# 7          6  California         41        Marin County  1990
# 8          6  California         41        Marin County  1995
# 9          6  California         41        Marin County  2000
# 10         6  California         41        Marin County  2005
# 11         6  California         41        Marin County  2010
# 12         6  California         97       Sonoma County  1985
# 13         6  California         97       Sonoma County  1990
# ...

# %%
counties[["Public Supply deliveries to domestic, in Mgal/d"]+["Public Supply deliveries to commercial, in Mgal/d"]+["Public Supply deliveries to industrial, in Mgal/d"]+["Public Supply deliveries to thermoelectric, in Mgal/d"]].median().plot()

# %%
counties=df.groupby("county_nm")

# %%
counties[["Public Supply deliveries to domestic, in Mgal/d"]+["Public Supply deliveries to commercial, in Mgal/d"]+["Public Supply deliveries to industrial, in Mgal/d"]+["Public Supply deliveries to thermoelectric, in Mgal/d"]].median().plot()

# %%
df=pd.read_csv("Five_counties.dat",sep="\t")

# %%
df
# Out:
#     state_cd  state_name  county_cd              county_nm  year  \
# 0          6  California         37     Los Angeles County  1985
# 1          6  California         37     Los Angeles County  1990
# 2          6  California         37     Los Angeles County  1995
# 3          6  California         37     Los Angeles County  2000
# 4          6  California         37     Los Angeles County  2005
# 5          6  California         37     Los Angeles County  2010
# 6          6  California         73       San Diego County  1985
# 7          6  California         73       San Diego County  1990
# 8          6  California         73       San Diego County  1995
# 9          6  California         73       San Diego County  2000
# 10         6  California         73       San Diego County  2005
# 11         6  California         73       San Diego County  2010
# 12         6  California         59          Orange County  1985
# ...

# %%
counties=df.groupby("county_nm")

# %%
counties[["Public Supply deliveries to domestic, in Mgal/d"]+["Public Supply deliveries to commercial, in Mgal/d"]+["Public Supply deliveries to industrial, in Mgal/d"]+["Public Supply deliveries to thermoelectric, in Mgal/d"]].median().plot()
